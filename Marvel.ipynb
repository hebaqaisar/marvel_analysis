# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
marvel = pd.read_csv("C:\\Users\\HIBA QAISAR\\Downloads\\marvel_demo_stats_powers.csv")

# %%
marvel.head()
# Out:
#    Unnamed: 0  ID           Name Alignment_x  Gender EyeColor  \
# 0           0   0         A-Bomb        good    Male   yellow
# 1           1   3    Abomination         bad    Male    green
# 2           2   4        Abraxas         bad    Male     blue
# 3           3   5  Absorbing Man         bad    Male     blue
# 4           4   8       Agent 13        good  Female     blue
#
#                 Race HairColor      Publisher SkinColor  ...  Web Creation  \
# 0              Human   No Hair  Marvel Comics         -  ...         False
# 1  Human / Radiation   No Hair  Marvel Comics         -  ...         False
# 2      Cosmic Entity     Black  Marvel Comics         -  ...         False
# 3              Human   No Hair  Marvel Comics         -  ...         False
# 4                  -     Blond  Marvel Comics         -  ...           NaN
#
#    Reality Warping  Odin Force  Symbiote Costume  Speed Force  Phoenix Force  \
# ...

# %%
marvel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 382 entries, 0 to 381
# Columns: 186 entries, Unnamed: 0 to Omniscient
# dtypes: float64(9), int64(2), object(175)
# memory usage: 555.2+ KB

# %%
marvel.shape
# Out:
# (382, 186)

# %%
marvel["Alignment_x"].value_counts()
# Out:
# Alignment_x
# good       254
# bad        114
# neutral     11
# -            3
# Name: count, dtype: int64

# %%
good = marvel[marvel["Alignment_x"]=='good']

# %%
good.head()
# Out:
#     Unnamed: 0  ID        Name Alignment_x  Gender EyeColor   Race HairColor  \
# 0            0   0      A-Bomb        good    Male   yellow  Human   No Hair
# 4            4   8    Agent 13        good  Female     blue      -     Blond
# 5            5   9   Agent Bob        good    Male    brown  Human     Brown
# 6            6  10  Agent Zero        good    Male        -      -         -
# 10          10  22       Angel        good    Male     blue      -     Blond
#
#         Publisher SkinColor  ...  Web Creation  Reality Warping  Odin Force  \
# 0   Marvel Comics         -  ...         False            False       False
# 4   Marvel Comics         -  ...           NaN              NaN         NaN
# 5   Marvel Comics         -  ...         False            False       False
# 6   Marvel Comics         -  ...         False            False       False
# 10  Marvel Comics         -  ...         False            False       False
#
# ...

# %%
bad = marvel[marvel["Alignment_x"]=='bad']

bad.head()
# Out:
#    Unnamed: 0  ID           Name Alignment_x Gender EyeColor  \
# 1           1   3    Abomination         bad   Male    green
# 2           2   4        Abraxas         bad   Male     blue
# 3           3   5  Absorbing Man         bad   Male     blue
# 7           7  11     Air-Walker         bad   Male     blue
# 8           8  12           Ajax         bad   Male    brown
#
#                 Race HairColor      Publisher SkinColor  ...  Web Creation  \
# 1  Human / Radiation   No Hair  Marvel Comics         -  ...         False
# 2      Cosmic Entity     Black  Marvel Comics         -  ...         False
# 3              Human   No Hair  Marvel Comics         -  ...         False
# 7                  -     White  Marvel Comics         -  ...         False
# 8             Cyborg     Black  Marvel Comics         -  ...         False
#
#    Reality Warping  Odin Force  Symbiote Costume  Speed Force  Phoenix Force  \
# ...

# %%
neutral = marvel[marvel["Alignment_x"]=='neutral']

neutral.head()
# Out:
#      Unnamed: 0   ID        Name Alignment_x  Gender EyeColor           Race  \
# 93           93  185     Copycat     neutral  Female      red         Mutant
# 106         106  212    Deadpool     neutral    Male    brown         Mutant
# 141         141  272    Galactus     neutral    Male    black  Cosmic Entity
# 149         149  284   Gladiator     neutral    Male     blue      Strontian
# 191         191  373  Juggernaut     neutral    Male     blue          Human
#
#     HairColor      Publisher SkinColor  ...  Web Creation  Reality Warping  \
# 93      White  Marvel Comics      blue  ...         False            False
# 106   No Hair  Marvel Comics         -  ...         False            False
# 141     Black  Marvel Comics         -  ...         False            False
# 149      Blue  Marvel Comics    purple  ...         False            False
# 191       Red  Marvel Comics         -  ...         False            False
#
# ...

# %%
plt.bar(good['Gender'].value_counts().keys(), good['Gender'].value_counts(), color = ['black', 'blue', 'purple'])
# Out:
# <BarContainer object of 3 artists>

# %%
#in seaborn

sns.countplot(data=good, x='Gender', palette=['black', 'blue', 'purple'])
# Out:
# C:\Users\HIBA QAISAR\AppData\Local\Temp\ipykernel_13860\2560394566.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=good, x='Gender', palette=['black', 'blue', 'purple'])
# <Axes: xlabel='Gender', ylabel='count'>

# %%
# Find all characters from Marvel Comics:

marvelComics = marvel[marvel['Publisher'] == 'Marvel Comics']
marvelComics
# Out:
#      Unnamed: 0   ID             Name Alignment_x  Gender EyeColor  \
# 0             0    0           A-Bomb        good    Male   yellow
# 1             1    3      Abomination         bad    Male    green
# 2             2    4          Abraxas         bad    Male     blue
# 3             3    5    Absorbing Man         bad    Male     blue
# 4             4    8         Agent 13        good  Female     blue
# ..          ...  ...              ...         ...     ...      ...
# 377         377  726            X-Man        good    Male     blue
# 378         378  727      Yellow Claw         bad    Male     blue
# 379         379  728     Yellowjacket        good    Male     blue
# 380         380  729  Yellowjacket II        good  Female     blue
# 381         381  730             Ymir        good    Male    white
#
#                   Race         HairColor      Publisher SkinColor  ...  \
# 0                Human           No Hair  Marvel Comics         -  ...
# ...

# %%
#Find characters with super speed (Speed Force)

speedsters = marvel[marvel['Speed Force'] == True]

speedsters
# Out:
# Empty DataFrame
# ...

# %%
#Get the top 5 most common races

marvel['Race'].value_counts().head(5)
# Out:
# Race
# -                    170
# Human                 83
# Mutant                56
# Human / Radiation     10
# Symbiote               8
# Name: count, dtype: int64

# %%
plt.bar(marvel['Race'].value_counts().keys())

# %%
#Find characters with Reality Warping & Time Travel abilities

time_warpers = marvel[(marvel['Reality Warping'] == True) & (marvel['Time Travel'] == True)]

time_warpers
# Out:
#      Unnamed: 0   ID               Name Alignment_x Gender      EyeColor  \
# 137         137  268  Franklin Richards        good   Male          blue
# 203         203  403             Legion        good   Male  green / blue
# 205         205  410    Living Tribunal     neutral      -          blue
# 255         255  503      One-Above-All     neutral      -             -
#
#               Race HairColor      Publisher SkinColor  ...  Web Creation  \
# 137         Mutant     Blond  Marvel Comics         -  ...         False
# 203         Mutant     Black  Marvel Comics         -  ...         False
# 205  Cosmic Entity   No Hair  Marvel Comics      gold  ...         False
# 255  Cosmic Entity         -  Marvel Comics         -  ...         False
#
#      Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# 137             True       False             False        False
# 203             True       False             False        False
# ...
